# %%
a = 1
b = 1.0
c = -49

# %%
a = '1'
print(type(a))
# Out:
# <class 'str'>

# %%
# list
l = []
l = list()

# %%
l = [1, 2, 3, 4, 5]

print(l[0])
print(l[-1])
print(l[2:4])
# Out:
# 1
# 5
# [3, 4]

# %%
l = [1, 'strings', [1, 2, 3]]

print(l)
for i in l:
    print(i)
# Out:
# [1, 'strings', [1, 2, 3]]
# 1
# strings
# [1, 2, 3]

# %%
# Tuples
t = ('apple', 'bottle', 'car')

print(type(t))
print(t[0])
# Out:
# <class 'tuple'>
# apple

# %%
# Dictionaries
d = {'a': 1, 'b': 2}

print(d['a'])
print(d['b'])

d['c'] = 3
print(d)
# Out:
# 1
# 2
# {'a': 1, 'b': 2, 'c': 3}

# %%
d = {'a': 1, 'b': 2, 'c': 3}
print(d.items())
print(d.keys())
print(d.values())
# Out:
# dict_items([('a', 1), ('b', 2), ('c', 3)])
# dict_keys(['a', 'b', 'c'])
# dict_values([1, 2, 3])
